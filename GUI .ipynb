# %%
from tkinter import * #importing tkinter
import webbrowser
from tkinter import ttk

root=Tk() #creating the root window

width_value=root.winfo_screenwidth()
height_value=root.winfo_screenheight()
root.geometry("%dx%d+0+0" % (width_value, height_value)) #fullscreen window
root.title("Oslo Metropolitan University") #adding a title
root.configure(background="white") #window colour

frame1=Frame(root, bg="white")

label1=Label(frame1, text="Info Kiosk\nOslo Metropolitan University", fg="#ffd500", bg="white", font="Verdana 32 bold italic", justify=LEFT)
label1.grid(row=1, column=4)

photo=PhotoImage(file="oslometlogo.gif") #adding image
w=Label(frame1, image=photo)
w.grid(row=1,column=2)

frame1.grid(row=0, column=0)

frame2=Frame(root, bg="white")
button2=Button(frame2, text="🏠︎ Home", fg="black", bg="#ffd500", font="Verdana 12 bold italic")


def open_Toplevel2(): #define a function for the second toplevel window
    top2=Toplevel(root)
    top2.title("Accessibility")
    width_value=top2.winfo_screenwidth()
    height_value=top2.winfo_screenheight()
    top2.geometry("%dx%d+0+0" % (width_value, height_value))
    top2.configure(background="#144BB8")
    def search():
        url=enter_box.get()
        webbrowser.open(url)
    
    frame_one=Frame(top2, bg="#144BB8")
    label_one=Label(frame_one, text="Accessibility Adjustments", fg="white", bg="#144BB8", font="Verdana 32 bold italic")    
    buttonno=Button(frame_one, text="🇳🇴 Norwegian", fg="#144BB8", bg="white", font="Verdana 12 bold italic")
    buttonus=Button(frame_one, text="🇺🇸 English", fg="#144BB8", bg="white", font="Verdana 12 bold italic")
    label_one.grid(row=3, column=4)
    buttonno.grid(row=0, column=18, padx=10, pady=10, ipadx=10, ipady=10)
    buttonus.grid(row=0, column=20, padx=10, pady=10, ipadx=10, ipady=10)
    frame_one.grid(row=0, column=0)
    
    frame_two=Frame(top2, bg="#144BB8")
    button_reset=Button(frame_two, text="🔁 Reset Settings", fg="#144BB8", bg="white", font="Verdana 12 bold italic")
    button_statment=Button(frame_two, text="📢 Statment", fg="#144BB8", bg="white", font="Verdana 12 bold italic")
    button_hide=Button(frame_two, text="🙈 Hide Interface", fg="#144BB8", bg="white", font="Verdana 12 bold italic")
    button_reset.grid(row=0, column=0, padx=10, pady=10, ipadx=10, ipady=10)
    button_statment.grid(row=0, column=15, padx=10, pady=10, ipadx=10, ipady=10)
    button_hide.grid(row=0, column=17, padx=10, pady=10, ipadx=10, ipady=10)
    frame_two.grid(row=2, column=0,ipadx=20, ipady=20, padx=20, pady=20)
    
    frame_three=Frame(top2,bg="#144BB8")
    label_search=Label(frame_three, text="Unclear content? Search in dictionary", fg="white", bg="#144BB8",font=("arial", 12, "bold"))
    enter_box=Entry(frame_three, width=35)
    search_button=Button(frame_three, text="Search", command=search, font=("arial", 12, "bold"))
    label_search.grid(row=0, column=0, padx=10, pady=10, ipadx=10, ipady=10)
    enter_box.grid(row=1, column=0)
    search_button.grid(row=1, column=1)
    frame_three.grid(row=3, column=0, padx=10, pady=10, ipadx=10, ipady=10)
    
    frame_four=Frame(top2,bg="white")
    choose_label=Label(frame_four, text="Choose the right accessibility profile for you",fg="#144BB8", bg="white", font="Verdana 17 bold italic")
    seizure_label=Label(frame_four, text="Seizure Safe Profile\nClear flashes & reduces color",fg="#144BB8", bg="white", font="Verdana 12 bold italic")    
    seizure_button=Button(frame_four, text="Click to turn On", fg="#144BB8", bg="white", font="Verdana 12 bold italic")
    vision_label=Label(frame_four, text="Vision Impared Profile\nEnhances website's visuals",fg="#144BB8", bg="white", font="Verdana 12 bold italic")    
    vision_button=Button(frame_four, text="Click to turn On", fg="#144BB8", bg="white", font="Verdana 12 bold italic")
    adhd_label=Label(frame_four, text="ADHD Friendly Profile\nMore focus & fewer distractions",fg="#144BB8", bg="white", font="Verdana 12 bold italic")    
    adhd_button=Button(frame_four, text="Click to turn On", fg="#144BB8", bg="white", font="Verdana 12 bold italic")
    cognitive_label=Label(frame_four, text="Cognitive Disability Profile\nAssist with reading & focusing",fg="#144BB8", bg="white", font="Verdana 12 bold italic")    
    cognitive_button=Button(frame_four, text="Click to turn On", fg="#144BB8", bg="white", font="Verdana 12 bold italic")
    motor_label=Label(frame_four, text="Keyboard Navigation (Motor)\nUse GUI with the keyboard",fg="#144BB8", bg="white", font="Verdana 12 bold italic")    
    motor_button=Button(frame_four, text="Click to turn On", fg="#144BB8", bg="white", font="Verdana 12 bold italic")
    blind_label=Label(frame_four, text="Blind Users (Screen Reader)\nOptimize website for screen_reader",fg="#144BB8", bg="white", font="Verdana 12 bold italic")    
    blind_button=Button(frame_four, text="Click to turn On", fg="#144BB8", bg="white", font="Verdana 12 bold italic")
    choose_label.grid(row=0, column=0)
    seizure_label.grid(row=1, column=0)
    seizure_button.grid(row=1, column=1, padx=10, pady=10, ipadx=10, ipady=10)
    vision_label.grid(row=2, column=0)
    vision_button.grid(row=2, column=1, padx=10, pady=10, ipadx=10, ipady=10)
    adhd_label.grid(row=3, column=0)
    adhd_button.grid(row=3, column=1, padx=10, pady=10, ipadx=10, ipady=10)
    cognitive_label.grid(row=4, column=0)
    cognitive_button.grid(row=4, column=1, padx=10, pady=10, ipadx=10, ipady=10)
    motor_label.grid(row=5, column=0)
    motor_button.grid(row=5, column=1, padx=10, pady=10, ipadx=10, ipady=10)
    blind_label.grid(row=6, column=0)
    blind_button.grid(row=6, column=1, padx=10, pady=10, ipadx=10, ipady=10)
    frame_four.grid(row=4, column=0)
    
    frame_five=Frame(top2,bg="#144BB8")
    button_back=Button(frame_five, text='🢀 Back', fg="black", bg="white", font="Verdana 12 bold italic", command=top2.destroy)
    button_back.grid(row=0, column=0,ipadx=20, ipady=20, padx=20, pady=20)
    frame_five.grid(row=5, column=0, ipadx=20, ipady=20, padx=20, pady=20)
    
    top2.mainloop()

button3=Button(frame2, text="♿ Accessibility ", fg="black", bg="#144BB8", font="Verdana 12 bold italic", command=open_Toplevel2)
button4=Button(frame2, text="🔊 Text to Speach", fg="black", bg="#2F14B8", font="Verdana 12 bold italic")
button5=Button(frame2, text="🇺🇸 English", fg="black", bg="#8114B8", font="Verdana 12 bold italic")


def open_Toplevel1(): # define a function for the first toplevel window
    top1=Toplevel(root)
    top1.title("storbyuniversitetet")
    width_value=top1.winfo_screenwidth()
    height_value=top1.winfo_screenheight()
    top1.geometry("%dx%d+0+0" % (width_value, height_value))
    top1.configure(background="white")
    
    frameone=Frame(top1, bg="white")
    labelone=Label(frameone, text="Info Kiosk\nSTORBYUNIVERSITETET", fg="#ffd500", bg="white", font="Verdana 32 bold italic", justify=LEFT)
    labelone.grid(row=1, column=4)
    photo1=PhotoImage(file="oslometlogo.gif")
    w1=Label(frameone, image=photo1)
    w1.grid(row=1,column=2)  
    frameone.grid(row=0, column=0)
    
    frametwo=Frame(top1, bg="white")
    button_home=Button(frametwo, text="🏠︎ Hjem", fg="black", bg="#ffd500", font="Verdana 12 bold italic")
    button_access=Button(frametwo, text="♿ Tilgjengelighet ", fg="black", bg="#144BB8", font="Verdana 12 bold italic")
    button_tts=Button(frametwo, text="🔊 Tekst til Tale", fg="black", bg="#2F14B8", font="Verdana 12 bold italic")
    button_us=Button(frametwo, text="🇺🇸 English", fg="black", bg="#8114B8", font="Verdana 12 bold italic")
    button_no=Button(frametwo, text="🇳🇴 Norsk", fg="black", bg="#8114B8", font="Verdana 12 bold italic")
    button_home.grid(row=0, column=0, padx=10, pady=10, ipadx=10, ipady=10)
    button_access.grid(row=0, column=15, padx=10, pady=10, ipadx=10, ipady=10)
    button_tts.grid(row=0, column=17, padx=10, pady=10, ipadx=10, ipady=10)
    button_us.grid(row=0, column=19, padx=10, pady=10, ipadx=10, ipady=10)
    button_no.grid(row=0, column=20, padx=10, pady=10, ipadx=10, ipady=10)
    frametwo.grid(row=1, column=0)
    
    framethree=Frame(top1, bg="white")
    button_eatdrink=Button(framethree, text="🍽 Mat&drikke", fg="black", bg="#ffd500", font="Verdana 12 bold italic")
    button_events=Button(framethree, text="🗓 Hva skjer", fg="black", bg="#ffd500", font="Verdana 12 bold italic")
    button_map=Button(framethree, text="📌 Kart", fg="black", bg="#ffd500", font="Verdana 12 bold italic")
    button_info=Button(framethree, text="🛈 Campus info", fg="black", bg="#ffd500", font="Verdana 12 bold italic")
    button_transport=Button(framethree, text="🚍 Offentlig transport", fg="black", bg="#ffd500", font="Verdana 12 bold italic")
    button_eatdrink.grid(row=0, column=1,ipadx=50, ipady=50, padx=40, pady=40)
    button_events.grid(row=0, column=2,ipadx=50, ipady=50, padx=40, pady=40)
    button_map.grid(row=0, column=3,ipadx=50, ipady=50, padx=40, pady=40)
    button_info.grid(row=0, column=4,ipadx=50, ipady=50, padx=40, pady=40)
    button_transport.grid(row=0, column=5,ipadx=50, ipady=50, padx=40, pady=40)
    framethree.grid(row=2, column=0,ipadx=50, ipady=50, padx=40, pady=40)
    
    frame4=Frame(top1,bg="white")
    back_button=Button(frame4, text='🢀 Tilbake', fg="black", bg="#ffd500", font="Verdana 12 bold italic", command=top1.destroy)
    back_button.grid(row=0, column=0,ipadx=20, ipady=20, padx=20, pady=20)
    frame4.grid(row=3, column=0)
    
    top1.mainloop()

button6=Button(frame2, text="🇳🇴 Norwegian", fg="black", bg="#8114B8", font="Verdana 12 bold italic", command=open_Toplevel1)
button2.grid(row=0, column=0, padx=10, pady=10, ipadx=10, ipady=10)
button3.grid(row=0, column=15, padx=10, pady=10, ipadx=10, ipady=10)
button4.grid(row=0, column=17, padx=10, pady=10, ipadx=10, ipady=10)
button5.grid(row=0, column=19, padx=10, pady=10, ipadx=10, ipady=10)
button6.grid(row=0, column=20, padx=10, pady=10, ipadx=10, ipady=10)
frame2.grid(row=1, column=0)


frame3=Frame(root, bg="white")

def open_Toplevel3(): #define a function for the third toplevel window
    top3=Toplevel(root)
    top3.title("Eat&Drink")
    width_value=top3.winfo_screenwidth()
    height_value=top3.winfo_screenheight()
    top3.geometry("%dx%d+0+0" % (width_value, height_value))
    top3.configure(background="white")
    
    frame_1=Frame(top3, bg="white")
    label_eat=Label(frame_1, text="Info Kiosk\nOslo Metropolitan University\n🍽 Eat&Drink", fg="#ffd500", bg="white", font="Verdana 32 bold italic", justify=LEFT)
    label_eat.grid(row=1, column=4)

    uni=PhotoImage(file="oslometlogo.gif")
    w2=Label(frame_1, image=uni)
    w2.grid(row=1,column=2)

    frame_1.grid(row=0, column=0)
    
    frame_2=Frame(top3, bg="white")
    button_canteens=Button(frame_2, text="Our Canteens and Coffeeshops", fg="white", bg="#ffd500", font="Verdana 12 bold italic")    
    button_deals=Button(frame_2, text="Students deals", fg="white", bg="#ffd500", font="Verdana 12 bold italic")
    button_catering=Button(frame_2, text="Catering", fg="white", bg="#ffd500", font="Verdana 12 bold italic")
    button_canteens.grid(row=0, column=4, padx=10, pady=10, ipadx=10, ipady=10)
    button_deals.grid(row=0, column=18, padx=10, pady=10, ipadx=10, ipady=10)
    button_catering.grid(row=0, column=20, padx=10, pady=10, ipadx=10, ipady=10)
    frame_2.grid(row=1, column=0,ipadx=50, ipady=50, padx=50, pady=50)
    
    
    frame_3=Frame(top3, bg="white")
    label_menu=Label(frame_3, text="Today's menu", fg="black", bg="white", font="Verdana 22 bold italic")    
    #creating combobox
    vlist=["Andrea spiseri", "Annas spiseri", "Hannas spiseri", "Kafe Årstien", "Olaf spiseri"] #combobox
    Combo=ttk.Combobox(frame_3, values=vlist)
    Combo.set("Choose restaurant")
    button_find=Button(frame_3, text="Find", fg="black", bg="#ffd500", font="Verdana 12 bold italic")
    label_menu.grid(row=0, column=0, padx=5, pady=5, ipadx=150, ipady=5)
    button_find.grid(row=6, column=0, padx=10, pady=10, ipadx=10, ipady=10)
    Combo.grid(row=5, column=0, padx=10, pady=10, ipadx=50, ipady=10)
    frame_3.grid(row=2, column=0)
    
    frame_4=Frame(top3,bg="white")
    backbutton=Button(frame_4, text='🢀 Back', fg="black", bg="#ffd500", font="Verdana 12 bold italic", command=top3.destroy)
    backbutton.grid(row=0, column=0,ipadx=20, ipady=20, padx=20, pady=20)
    frame_4.grid(row=3, column=0, ipadx=70, ipady=70, padx=70, pady=70)
    
    top3.mainloop()

button7=Button(frame3, text="🍽 Eat&Drink", fg="black", bg="#ffd500", font="Verdana 12 bold italic", command=open_Toplevel3)
button8=Button(frame3, text="🗓 Events", fg="black", bg="#ffd500", font="Verdana 12 bold italic")

def open_Toplevel4(): #define a function for the forth toplevel window
    #create widget
    top4=Toplevel(root)
    #define tittle
    top4.title("Map")
    #fullscreen size window
    width_value=top4.winfo_screenwidth()
    height_value=top4.winfo_screenheight()
    top4.geometry("%dx%d+0+0" % (width_value, height_value))
    top4.configure(background="white")
    
    def callback(url):
        webbrowser.open_new(url)
    
    f1=Frame(top4, bg="white")
    label_map=Label(f1, text="Info Kiosk\nOslo Metropolitan University\n📌 Map", fg="#ffd500", bg="white", font="Verdana 32 bold italic", justify=LEFT)
    label_map.grid(row=1, column=4)

    metuni=PhotoImage(file="oslometlogo.gif")
    uni=Label(f1, image=metuni)
    uni.grid(row=1,column=2)

    f1.grid(row=0, column=0)
    
    f2=Frame(top4, bg="white")
    maplbl=Label(f2, text="Pilestredet Campus\nOsloMet’s largest campus is located in the centre of Oslo.", fg="black", bg="white", font="Verdana 22 bold italic")    
    maplbl.grid(row=0, column=0, padx=10, pady=10, ipadx=10, ipady=10)
    f2.grid(row=1, column=0,ipadx=50, ipady=50, padx=50, pady=50)
    
    
    f3=Frame(top4, bg="white")
    adresslbl=Label(f3, text="Address\nPilestredet 32 - 54", fg="black", bg="white", font="Verdana 22 bold italic")    
    adresslbl.grid(row=0, column=0, padx=10, pady=10, ipadx=10, ipady=10)
    
    #creating hyperlinks
    link1=Label(f3, text="View on Google Maps 🡵", fg="black", bg="white", font="Verdana 12 bold italic underline", cursor="hand2")
    link1.grid(row=1, column=0)
    link1.bind("<Button-1>", lambda e: callback("https://www.google.no/maps/place/Pilestredet+46,+0167+Oslo/@59.9210891,10.7328447,19z/data=!4m5!3m4!1s0x46416e7913e2a529:0x15d03622a70f16df!8m2!3d59.9210891!4d10.7333919"))
    
    link2=Label(f3, text="View building on MazeMap 🡵", fg="black", bg="white", font="Verdana 12 bold italic underline", cursor="hand2")
    link2.grid(row=2, column=0)
    link2.bind("<Button-1>", lambda e: callback("https://use.mazemap.com/#v=1&zlevel=1&center=10.733352,59.921070&zoom=18.1&campusid=53"))

    f3.grid(row=2, column=0)
    
    f4=Frame(top4,bg="white")
    #create back/exit button
    bckbutton=Button(f4, text='🢀 Back', fg="black", bg="#ffd500", font="Verdana 12 bold italic", command=top4.destroy)
    bckbutton.grid(row=0, column=0,ipadx=20, ipady=20, padx=20, pady=20)
    f4.grid(row=3, column=0, ipadx=70, ipady=70, padx=70, pady=70)
    
    top4.mainloop()

button9=Button(frame3, text="📌 Map", fg="black", bg="#ffd500", font="Verdana 12 bold italic", command=open_Toplevel4)
button10=Button(frame3, text="🛈 On campus information", fg="black", bg="#ffd500", font="Verdana 12 bold italic")
button11=Button(frame3, text="🚍 Public transport timetable", fg="black", bg="#ffd500", font="Verdana 12 bold italic")
button7.grid(row=0, column=1,ipadx=50, ipady=50, padx=50, pady=50)
button8.grid(row=0, column=2,ipadx=50, ipady=50, padx=50, pady=50)
button9.grid(row=0, column=3,ipadx=50, ipady=50, padx=50, pady=50)
button10.grid(row=0, column=4,ipadx=50, ipady=50, padx=50, pady=50)
button11.grid(row=0, column=5,ipadx=50, ipady=50, padx=50, pady=50)
frame3.grid(row=2, column=0,ipadx=50, ipady=50, padx=50, pady=50)


root.mainloop() #running window on continous loop
